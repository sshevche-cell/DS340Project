# %%
import pandas as pd

df = pd.read_csv('/content/VIXCLS.csv')
display(df.head())
# Out:
#   observation_date  VIXCLS
# 0       1990-01-02   17.24
# 1       1990-01-03   18.19
# 2       1990-01-04   19.22
# 3       1990-01-05   20.11
# 4       1990-01-08   20.26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  9357 non-null   object
#  1   VIXCLS            9058 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 146.3+ KB

# %%
df['observation_date'] = pd.to_datetime(df['observation_date'])
df['VIXCLS'] = df['VIXCLS'].interpolate(method='linear')

display(df.head())
df.info()
# Out:
#   observation_date  VIXCLS
# 0       1990-01-02   17.24
# 1       1990-01-03   18.19
# 2       1990-01-04   19.22
# 3       1990-01-05   20.11
# 4       1990-01-08   20.26
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  9357 non-null   datetime64[ns]
#  1   VIXCLS            9357 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 146.3 KB
