# %% [markdown]
# ## Load Excel Data
#
# Load the 'fed_news_sentiment_data.xlsx' file into a pandas DataFrame.

# %%
import pandas as pd
df = pd.read_excel('/content/fed_news_sentiment_data.xlsx')
df.head()
# Out:
#   This spreadsheet contains updated data series from "News Sentiment in the Time of COVID-19"  \
# 0  by Shelby R. Buckman, Adam Hale Shapiro, Morit...
# 1  Federal Reserve Bank of San Francisco FRBSF Ec...
# 2  https://www.frbsf.org/economic-research/public...
# 3                                                NaN
# 4  The Data tab contains a news sentiment measure...
#
#    Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0         NaN         NaN        NaN         NaN         NaN        NaN
# 1         NaN         NaN        NaN         NaN         NaN        NaN
# 2         NaN         NaN        NaN         NaN         NaN        NaN
# 3         NaN         NaN        NaN         NaN         NaN        NaN
# 4         NaN         NaN        NaN         NaN         NaN        NaN
#
#    Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0         NaN         NaN        NaN
# 1         NaN         NaN        NaN
# 2         NaN         NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   This spreadsheet contains updated data series from "News Sentiment in the Time of COVID-19"  19 non-null     object
#  1   Unnamed: 1                                                                                   0 non-null      float64
#  2   Unnamed: 2                                                                                   0 non-null      float64
#  3   Unnamed: 3                                                                                   6 non-null      object
#  4   Unnamed: 4                                                                                   0 non-null      float64
# ...

# %%
df.iloc[5:15]
# Out:
#    This spreadsheet contains updated data series from "News Sentiment in the Time of COVID-19"  \
# 5   The units are the day fixed effects from the f...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                               Where
# 10                                                NaN
# 11  o             is the positivity score for arti...
# 12     o             is a sample-day (t) fixed effect
# 13  o                     is a newspaper*type fixe...
# 14                                                NaN
#
#     Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 5          NaN         NaN        NaN         NaN         NaN        NaN
# 6          NaN         NaN        NaN         NaN         NaN        NaN
# 7          NaN         NaN        NaN         NaN         NaN        NaN
# ...

# %%
df.iloc[15:26]
# Out:
#    This spreadsheet contains updated data series from "News Sentiment in the Time of COVID-19"  \
# 15  Details about the data and methodology can be ...
# 16                                                NaN
# 17  Shapiro, Adam Hale, Moritz Sudhof, and Daniel ...
# 18      Federal Reserve Bank of San Francisco Work...
# 19                                                NaN
# 20  As of April 2021, the series was updated to us...
# 21                       Atlanta Journal-Constitution
# 22                                      Boston Herald
# 23                                Dallas Morning News
# 24                                 Detroit Free Press
# 25                                  Houston Chronicle
#
#     Unnamed: 1  Unnamed: 2               Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 15         NaN         NaN                      NaN         NaN         NaN
# 16         NaN         NaN                      NaN         NaN         NaN
# ...

# %%
df.iloc[26]
# Out:
# This spreadsheet contains updated data series from "News Sentiment in the Time of COVID-19"           New York Post
# Unnamed: 1                                                                                                       NaN
# Unnamed: 2                                                                                                       NaN
# Unnamed: 3                                                                                     San Jose Mercury News
# Unnamed: 4                                                                                                       NaN
# Unnamed: 5                                                                                                       NaN
# Unnamed: 6                                                                                            The Tennessean
# Unnamed: 7                                                                                                       NaN
# ...

# %%
excel_file = pd.ExcelFile('/content/fed_news_sentiment_data.xlsx')
print(excel_file.sheet_names)
# Out:
# ['Methodology', 'Data']

# %%
df = pd.read_excel('/content/fed_news_sentiment_data.xlsx', sheet_name='Data')
df.head()
# Out:
#         date  News Sentiment
# 0 1980-01-01       -0.037941
# 1 1980-01-02       -0.106681
# 2 1980-01-03       -0.089540
# 3 1980-01-05       -0.067275
# 4 1980-01-06       -0.089171

# %% [markdown]
# ## Inspect Data for Cleaning
#
#
# Inspect the loaded DataFrame to identify potential issues such as missing values, incorrect data types, or duplicates that may require cleaning.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16731 entries, 0 to 16730
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            16731 non-null  datetime64[ns]
#  1   News Sentiment  16731 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 261.6 KB

# %%
df.isnull().sum()
# Out:
# date              0
# News Sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                                 date  News Sentiment
# count                          16731    16731.000000
# mean   2002-12-14 17:31:29.402904832        0.009058
# min              1980-01-01 00:00:00       -0.714476
# 25%              1991-07-03 12:00:00       -0.098651
# 50%              2002-12-15 00:00:00        0.018938
# 75%              2014-05-28 12:00:00        0.136456
# max              2025-11-09 00:00:00        0.454118
# std                              NaN        0.181595

# %% [markdown]
# ## Convert to CSV
#
# Saving the cleaned DataFrame to a new CSV file, ensuring proper encoding.

# %%
df.to_csv('fed_news_sentiment_data.csv', index=False)
print('DataFrame successfully saved to fed_news_sentiment_data.csv')
# Out:
# DataFrame successfully saved to fed_news_sentiment_data.csv
